# %%
# Import the dependencies.
import pandas as pd
import numpy as np
import requests
from config import weather_api_key
from citipy import citipy
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 737

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
#        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":city_desc,
                          "Country": city_country
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cape town
# Processing Record 2 of Set 1 | araouane
# Processing Record 3 of Set 1 | bambanglipuro
# Processing Record 4 of Set 1 | lompoc
# Processing Record 5 of Set 1 | tasiilaq
# Processing Record 6 of Set 1 | arcata
# Processing Record 7 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 8 of Set 1 | provideniya
# Processing Record 9 of Set 1 | pangnirtung
# Processing Record 10 of Set 1 | carnarvon
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | yanan
# City not found. Skipping...
# Processing Record 13 of Set 1 | berlevag
# Processing Record 14 of Set 1 | ribeira grande
# Processing Record 15 of Set 1 | neiafu
# Processing Record 16 of Set 1 | bredasdorp
# Processing Record 17 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 1 | souillac
# Processing Record 20 of Set 1 | kahului
# Processing Record 21 of Set 1 | porto velho
# Processing Record 22 of Set 1 | zhigansk
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | new norfolk
# Processing Record 25 of Set 1 | atuona
# Processing Record 26 of Set 1 | kapaa
# Processing Record 27 of Set 1 | tuatapere
# Processing Record 28 of Set 1 | marawi
# Processing Record 29 of Set 1 | bluff
# Processing Record 30 of Set 1 | katsuura
# Processing Record 31 of Set 1 | tezu
# Processing Record 32 of Set 1 | olafsvik
# Processing Record 33 of Set 1 | leningradskiy
# Processing Record 34 of Set 1 | cumaribo
# City not found. Skipping...
# Processing Record 35 of Set 1 | mar del plata
# Processing Record 36 of Set 1 | port alfred
# Processing Record 37 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 1 | peleduy
# Processing Record 39 of Set 1 | esperance
# Processing Record 40 of Set 1 | thompson
# Processing Record 41 of Set 1 | chokurdakh
# Processing Record 42 of Set 1 | hermanus
# Processing Record 43 of Set 1 | hobart
# Processing Record 44 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 45 of Set 1 | nikolskoye
# Processing Record 46 of Set 1 | albany
# Processing Record 47 of Set 1 | sao gabriel da cachoeira
# Processing Record 48 of Set 1 | ushuaia
# Processing Record 49 of Set 1 | avarua
# Processing Record 50 of Set 1 | hilo
# Processing Record 1 of Set 2 | vikhorevka
# Processing Record 2 of Set 2 | puerto ayora
# Processing Record 3 of Set 2 | thunder bay
# Processing Record 4 of Set 2 | el wasta
# City not found. Skipping...
# Processing Record 5 of Set 2 | ponta do sol
# Processing Record 6 of Set 2 | cayenne
# Processing Record 7 of Set 2 | moerai
# Processing Record 8 of Set 2 | busselton
# Processing Record 9 of Set 2 | wilmington island
# Processing Record 10 of Set 2 | estevan
# Processing Record 11 of Set 2 | puerto penasco
# Processing Record 12 of Set 2 | kodiak
# Processing Record 13 of Set 2 | talnakh
# Processing Record 14 of Set 2 | fethiye
# Processing Record 15 of Set 2 | la ronge
# Processing Record 16 of Set 2 | kayerkan
# Processing Record 17 of Set 2 | hithadhoo
# Processing Record 18 of Set 2 | burnie
# Processing Record 19 of Set 2 | arraial do cabo
# Processing Record 20 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 21 of Set 2 | rikitea
# Processing Record 22 of Set 2 | north bend
# Processing Record 23 of Set 2 | san carlos del zulia
# Processing Record 24 of Set 2 | koslan
# Processing Record 25 of Set 2 | arman
# Processing Record 26 of Set 2 | kautokeino
# Processing Record 27 of Set 2 | aklavik
# Processing Record 28 of Set 2 | forestville
# Processing Record 29 of Set 2 | laguna
# Processing Record 30 of Set 2 | east london
# Processing Record 31 of Set 2 | deer lake
# Processing Record 32 of Set 2 | saskylakh
# Processing Record 33 of Set 2 | lavrentiya
# Processing Record 34 of Set 2 | cherskiy
# Processing Record 35 of Set 2 | coquimbo
# Processing Record 36 of Set 2 | bethel
# Processing Record 37 of Set 2 | dikson
# Processing Record 38 of Set 2 | barrow
# Processing Record 39 of Set 2 | verkhovazhye
# Processing Record 40 of Set 2 | urzhum
# Processing Record 41 of Set 2 | los llanos de aridane
# Processing Record 42 of Set 2 | yarada
# Processing Record 43 of Set 2 | itarema
# Processing Record 44 of Set 2 | savonlinna
# Processing Record 45 of Set 2 | tuktoyaktuk
# Processing Record 46 of Set 2 | adrar
# Processing Record 47 of Set 2 | mahebourg
# Processing Record 48 of Set 2 | honningsvag
# Processing Record 49 of Set 2 | ambagarh chauki
# Processing Record 50 of Set 2 | bambous virieux
# Processing Record 1 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 3 | castro
# Processing Record 3 of Set 3 | pilar
# Processing Record 4 of Set 3 | saint-philippe
# Processing Record 5 of Set 3 | vaini
# Processing Record 6 of Set 3 | lasa
# Processing Record 7 of Set 3 | namibe
# Processing Record 8 of Set 3 | yellowknife
# Processing Record 9 of Set 3 | naze
# Processing Record 10 of Set 3 | margate
# Processing Record 11 of Set 3 | tura
# Processing Record 12 of Set 3 | guane
# Processing Record 13 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 3 | houlung
# City not found. Skipping...
# Processing Record 15 of Set 3 | limon
# Processing Record 16 of Set 3 | maceio
# Processing Record 17 of Set 3 | vardo
# Processing Record 18 of Set 3 | jamestown
# Processing Record 19 of Set 3 | qaanaaq
# Processing Record 20 of Set 3 | jinji
# Processing Record 21 of Set 3 | georgetown
# Processing Record 22 of Set 3 | sitka
# Processing Record 23 of Set 3 | nemuro
# Processing Record 24 of Set 3 | makakilo city
# Processing Record 25 of Set 3 | talara
# Processing Record 26 of Set 3 | kamina
# Processing Record 27 of Set 3 | longyearbyen
# Processing Record 28 of Set 3 | guiratinga
# Processing Record 29 of Set 3 | chandbali
# Processing Record 30 of Set 3 | khammam
# Processing Record 31 of Set 3 | mount gambier
# Processing Record 32 of Set 3 | bodden town
# Processing Record 33 of Set 3 | udachnyy
# Processing Record 34 of Set 3 | airai
# Processing Record 35 of Set 3 | hashtrud
# Processing Record 36 of Set 3 | hay river
# Processing Record 37 of Set 3 | sovetskiy
# Processing Record 38 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 3 | pisco
# Processing Record 40 of Set 3 | butaritari
# Processing Record 41 of Set 3 | santa isabel
# Processing Record 42 of Set 3 | oak ridge
# Processing Record 43 of Set 3 | manbij
# Processing Record 44 of Set 3 | saint-joseph
# Processing Record 45 of Set 3 | lazaro cardenas
# Processing Record 46 of Set 3 | tommot
# Processing Record 47 of Set 3 | weymouth
# Processing Record 48 of Set 3 | togur
# Processing Record 49 of Set 3 | portland
# Processing Record 50 of Set 3 | ode
# Processing Record 1 of Set 4 | mergui
# City not found. Skipping...
# Processing Record 2 of Set 4 | ha tinh
# Processing Record 3 of Set 4 | batagay-alyta
# Processing Record 4 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 5 of Set 4 | khonsar
# City not found. Skipping...
# Processing Record 6 of Set 4 | grindavik
# Processing Record 7 of Set 4 | muskogee
# Processing Record 8 of Set 4 | cauquenes
# Processing Record 9 of Set 4 | padang
# Processing Record 10 of Set 4 | port-gentil
# Processing Record 11 of Set 4 | lisala
# Processing Record 12 of Set 4 | sinkat
# City not found. Skipping...
# Processing Record 13 of Set 4 | karratha
# Processing Record 14 of Set 4 | congonhas
# Processing Record 15 of Set 4 | huilong
# Processing Record 16 of Set 4 | bathsheba
# Processing Record 17 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 18 of Set 4 | camana
# Processing Record 19 of Set 4 | mianyang
# Processing Record 20 of Set 4 | jiuquan
# Processing Record 21 of Set 4 | tiksi
# Processing Record 22 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 23 of Set 4 | khurda
# Processing Record 24 of Set 4 | khatanga
# Processing Record 25 of Set 4 | umm lajj
# Processing Record 26 of Set 4 | ancud
# Processing Record 27 of Set 4 | leticia
# Processing Record 28 of Set 4 | ulaangom
# Processing Record 29 of Set 4 | juegang
# Processing Record 30 of Set 4 | fatikchhari
# City not found. Skipping...
# Processing Record 31 of Set 4 | luderitz
# Processing Record 32 of Set 4 | oussouye
# Processing Record 33 of Set 4 | aitape
# Processing Record 34 of Set 4 | itoman
# Processing Record 35 of Set 4 | olinda
# Processing Record 36 of Set 4 | peniche
# Processing Record 37 of Set 4 | linxia
# Processing Record 38 of Set 4 | port hedland
# Processing Record 39 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 40 of Set 4 | birjand
# Processing Record 41 of Set 4 | dhidhdhoo
# Processing Record 42 of Set 4 | sataua
# City not found. Skipping...
# Processing Record 43 of Set 4 | kruisfontein
# Processing Record 44 of Set 4 | kaeo
# Processing Record 45 of Set 4 | oyama
# Processing Record 46 of Set 4 | faanui
# Processing Record 47 of Set 4 | nanortalik
# Processing Record 48 of Set 4 | luziania
# Processing Record 49 of Set 4 | imbituba
# Processing Record 50 of Set 4 | cienfuegos
# Processing Record 1 of Set 5 | haines junction
# Processing Record 2 of Set 5 | victoria
# Processing Record 3 of Set 5 | salina cruz
# Processing Record 4 of Set 5 | okakarara
# Processing Record 5 of Set 5 | clyde river
# Processing Record 6 of Set 5 | ada
# Processing Record 7 of Set 5 | touros
# Processing Record 8 of Set 5 | lorengau
# Processing Record 9 of Set 5 | fraserburgh
# Processing Record 10 of Set 5 | awbari
# Processing Record 11 of Set 5 | mahaicony
# City not found. Skipping...
# Processing Record 12 of Set 5 | acarau
# Processing Record 13 of Set 5 | islamkot
# Processing Record 14 of Set 5 | thinadhoo
# Processing Record 15 of Set 5 | brigham city
# Processing Record 16 of Set 5 | tsumeb
# Processing Record 17 of Set 5 | kaitangata
# Processing Record 18 of Set 5 | porbandar
# Processing Record 19 of Set 5 | cap malheureux
# Processing Record 20 of Set 5 | kirakira
# Processing Record 21 of Set 5 | porto novo
# Processing Record 22 of Set 5 | raudeberg
# Processing Record 23 of Set 5 | karamay
# City not found. Skipping...
# Processing Record 24 of Set 5 | hunza
# City not found. Skipping...
# Processing Record 25 of Set 5 | kenai
# Processing Record 26 of Set 5 | salalah
# Processing Record 27 of Set 5 | varna
# Processing Record 28 of Set 5 | tshikapa
# Processing Record 29 of Set 5 | surt
# Processing Record 30 of Set 5 | caidian
# Processing Record 31 of Set 5 | henties bay
# Processing Record 32 of Set 5 | nouakchott
# Processing Record 33 of Set 5 | san andres
# Processing Record 34 of Set 5 | mehamn
# Processing Record 35 of Set 5 | tadepallegudem
# Processing Record 36 of Set 5 | gewane
# Processing Record 37 of Set 5 | kavaratti
# Processing Record 38 of Set 5 | esso
# Processing Record 39 of Set 5 | novodzherelievskaya
# City not found. Skipping...
# Processing Record 40 of Set 5 | sambava
# Processing Record 41 of Set 5 | sept-iles
# Processing Record 42 of Set 5 | nipawin
# Processing Record 43 of Set 5 | edd
# Processing Record 44 of Set 5 | acajutla
# Processing Record 45 of Set 5 | rawson
# Processing Record 46 of Set 5 | cartagena
# Processing Record 47 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 48 of Set 5 | razole
# Processing Record 49 of Set 5 | rio gallegos
# Processing Record 50 of Set 5 | tautira
# Processing Record 1 of Set 6 | podhum
# Processing Record 2 of Set 6 | jambi
# Processing Record 3 of Set 6 | segou
# Processing Record 4 of Set 6 | hobyo
# Processing Record 5 of Set 6 | narsaq
# Processing Record 6 of Set 6 | cidreira
# Processing Record 7 of Set 6 | kirensk
# Processing Record 8 of Set 6 | cordoba
# Processing Record 9 of Set 6 | atherton
# Processing Record 10 of Set 6 | espanola
# Processing Record 11 of Set 6 | namatanai
# Processing Record 12 of Set 6 | lebu
# Processing Record 13 of Set 6 | anadyr
# Processing Record 14 of Set 6 | san quintin
# Processing Record 15 of Set 6 | manacor
# Processing Record 16 of Set 6 | khor
# Processing Record 17 of Set 6 | chuy
# Processing Record 18 of Set 6 | meulaboh
# Processing Record 19 of Set 6 | inhambane
# Processing Record 20 of Set 6 | vao
# Processing Record 21 of Set 6 | opobo
# City not found. Skipping...
# Processing Record 22 of Set 6 | anar darreh
# City not found. Skipping...
# Processing Record 23 of Set 6 | troitskoye
# Processing Record 24 of Set 6 | ndende
# Processing Record 25 of Set 6 | cabo san lucas
# Processing Record 26 of Set 6 | kaduy
# Processing Record 27 of Set 6 | lafiagi
# Processing Record 28 of Set 6 | sompeta
# Processing Record 29 of Set 6 | salinopolis
# Processing Record 30 of Set 6 | sao felix do xingu
# Processing Record 31 of Set 6 | broken hill
# Processing Record 32 of Set 6 | aleksandrov gay
# Processing Record 33 of Set 6 | brae
# Processing Record 34 of Set 6 | kormilovka
# Processing Record 35 of Set 6 | ngunguru
# Processing Record 36 of Set 6 | bengkulu
# Processing Record 37 of Set 6 | ahipara
# Processing Record 38 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 39 of Set 6 | atambua
# Processing Record 40 of Set 6 | saint george
# Processing Record 41 of Set 6 | denizli
# Processing Record 42 of Set 6 | grand-santi
# Processing Record 43 of Set 6 | barra do garcas
# Processing Record 44 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 45 of Set 6 | nassau
# Processing Record 46 of Set 6 | buraydah
# Processing Record 47 of Set 6 | sioux lookout
# Processing Record 48 of Set 6 | diest
# Processing Record 49 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 50 of Set 6 | ucluelet
# Processing Record 1 of Set 7 | pietarsaari
# Processing Record 2 of Set 7 | egvekinot
# Processing Record 3 of Set 7 | aksarka
# Processing Record 4 of Set 7 | pochutla
# Processing Record 5 of Set 7 | tabunok
# Processing Record 6 of Set 7 | san jose
# Processing Record 7 of Set 7 | havre-saint-pierre
# Processing Record 8 of Set 7 | kargasok
# Processing Record 9 of Set 7 | tromso
# Processing Record 10 of Set 7 | bulungu
# Processing Record 11 of Set 7 | rolim de moura
# City not found. Skipping...
# Processing Record 12 of Set 7 | khasan
# Processing Record 13 of Set 7 | atar
# Processing Record 14 of Set 7 | grand gaube
# Processing Record 15 of Set 7 | obo
# Processing Record 16 of Set 7 | saldanha
# Processing Record 17 of Set 7 | havelock
# Processing Record 18 of Set 7 | port elizabeth
# Processing Record 19 of Set 7 | hervey bay
# Processing Record 20 of Set 7 | auki
# Processing Record 21 of Set 7 | cadillac
# Processing Record 22 of Set 7 | ketchikan
# Processing Record 23 of Set 7 | petit goave
# Processing Record 24 of Set 7 | riyadh
# Processing Record 25 of Set 7 | cockburn town
# Processing Record 26 of Set 7 | coihaique
# Processing Record 27 of Set 7 | nishihara
# Processing Record 28 of Set 7 | paamiut
# Processing Record 29 of Set 7 | kabinda
# Processing Record 30 of Set 7 | eyrarbakki
# Processing Record 31 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 32 of Set 7 | klaksvik
# Processing Record 33 of Set 7 | yangjiang
# Processing Record 34 of Set 7 | pandharpur
# Processing Record 35 of Set 7 | vanimo
# Processing Record 36 of Set 7 | hasaki
# Processing Record 37 of Set 7 | taoudenni
# Processing Record 38 of Set 7 | gaimersheim
# Processing Record 39 of Set 7 | fort saint john
# City not found. Skipping...
# Processing Record 40 of Set 7 | sungaipenuh
# Processing Record 41 of Set 7 | constitucion
# Processing Record 42 of Set 7 | mandan
# Processing Record 43 of Set 7 | great yarmouth
# Processing Record 44 of Set 7 | conceicao do araguaia
# Processing Record 45 of Set 7 | upernavik
# Processing Record 46 of Set 7 | port moresby
# Processing Record 47 of Set 7 | port lincoln
# Processing Record 48 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 49 of Set 7 | iqaluit
# Processing Record 50 of Set 7 | zhuji
# Processing Record 1 of Set 8 | santa isabel do rio negro
# Processing Record 2 of Set 8 | skjervoy
# Processing Record 3 of Set 8 | romny
# Processing Record 4 of Set 8 | flinders
# Processing Record 5 of Set 8 | barrhead
# Processing Record 6 of Set 8 | eyl
# Processing Record 7 of Set 8 | kangaatsiaq
# Processing Record 8 of Set 8 | banepa
# Processing Record 9 of Set 8 | korla
# Processing Record 10 of Set 8 | fortuna foothills
# Processing Record 11 of Set 8 | san cristobal
# Processing Record 12 of Set 8 | freeport
# Processing Record 13 of Set 8 | maniitsoq
# Processing Record 14 of Set 8 | coari
# Processing Record 15 of Set 8 | sur
# Processing Record 16 of Set 8 | isangel
# Processing Record 17 of Set 8 | luanda
# Processing Record 18 of Set 8 | ilulissat
# Processing Record 19 of Set 8 | kulhudhuffushi
# Processing Record 20 of Set 8 | fortuna
# Processing Record 21 of Set 8 | qiqihar
# Processing Record 22 of Set 8 | hofn
# Processing Record 23 of Set 8 | okoneshnikovo
# Processing Record 24 of Set 8 | blytheville
# Processing Record 25 of Set 8 | evanston
# Processing Record 26 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 28 of Set 8 | mareeba
# Processing Record 29 of Set 8 | majene
# Processing Record 30 of Set 8 | lunglei
# Processing Record 31 of Set 8 | varginha
# Processing Record 32 of Set 8 | pensacola
# Processing Record 33 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 8 | alofi
# Processing Record 35 of Set 8 | ornes
# Processing Record 36 of Set 8 | newton
# Processing Record 37 of Set 8 | camacha
# Processing Record 38 of Set 8 | general roca
# Processing Record 39 of Set 8 | mago
# Processing Record 40 of Set 8 | yeovil
# Processing Record 41 of Set 8 | fairbanks
# Processing Record 42 of Set 8 | kununurra
# Processing Record 43 of Set 8 | filadelfia
# Processing Record 44 of Set 8 | norman wells
# Processing Record 45 of Set 8 | paradwip
# City not found. Skipping...
# Processing Record 46 of Set 8 | charters towers
# Processing Record 47 of Set 8 | ranong
# Processing Record 48 of Set 8 | torbay
# Processing Record 49 of Set 8 | pevek
# Processing Record 50 of Set 8 | olden
# Processing Record 1 of Set 9 | gizo
# Processing Record 2 of Set 9 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 9 | asau
# Processing Record 4 of Set 9 | sao joao da barra
# Processing Record 5 of Set 9 | anloga
# Processing Record 6 of Set 9 | moranbah
# Processing Record 7 of Set 9 | dali
# Processing Record 8 of Set 9 | hami
# Processing Record 9 of Set 9 | caravelas
# Processing Record 10 of Set 9 | zyryanka
# Processing Record 11 of Set 9 | sao filipe
# Processing Record 12 of Set 9 | manzanillo
# Processing Record 13 of Set 9 | itaueira
# Processing Record 14 of Set 9 | plettenberg bay
# Processing Record 15 of Set 9 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 16 of Set 9 | lagoa
# Processing Record 17 of Set 9 | hollins
# Processing Record 18 of Set 9 | thasos
# Processing Record 19 of Set 9 | severomuysk
# Processing Record 20 of Set 9 | labuhan
# Processing Record 21 of Set 9 | paita
# Processing Record 22 of Set 9 | joson
# Processing Record 23 of Set 9 | do gonbadan
# Processing Record 24 of Set 9 | palmer
# Processing Record 25 of Set 9 | husavik
# Processing Record 26 of Set 9 | alice springs
# Processing Record 27 of Set 9 | honiara
# Processing Record 28 of Set 9 | port hardy
# Processing Record 29 of Set 9 | wamba
# Processing Record 30 of Set 9 | shelburne
# Processing Record 31 of Set 9 | orodara
# Processing Record 32 of Set 9 | baykit
# Processing Record 33 of Set 9 | la palma
# Processing Record 34 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 35 of Set 9 | saint anthony
# Processing Record 36 of Set 9 | gwadar
# Processing Record 37 of Set 9 | kailua
# Processing Record 38 of Set 9 | mutsu
# Processing Record 39 of Set 9 | doboz
# Processing Record 40 of Set 9 | orchard homes
# Processing Record 41 of Set 9 | upington
# Processing Record 42 of Set 9 | whitehorse
# Processing Record 43 of Set 9 | arua
# Processing Record 44 of Set 9 | santa maria
# Processing Record 45 of Set 9 | axim
# Processing Record 46 of Set 9 | bud
# Processing Record 47 of Set 9 | salinas
# Processing Record 48 of Set 9 | antalaha
# Processing Record 49 of Set 9 | goderich
# Processing Record 50 of Set 9 | venado tuerto
# Processing Record 1 of Set 10 | tupik
# Processing Record 2 of Set 10 | ostrovnoy
# Processing Record 3 of Set 10 | wewak
# Processing Record 4 of Set 10 | kunming
# Processing Record 5 of Set 10 | tongliao
# Processing Record 6 of Set 10 | oarai
# Processing Record 7 of Set 10 | tabou
# Processing Record 8 of Set 10 | vestmannaeyjar
# Processing Record 9 of Set 10 | ust-kut
# Processing Record 10 of Set 10 | kasangulu
# Processing Record 11 of Set 10 | xuddur
# Processing Record 12 of Set 10 | banyo
# Processing Record 13 of Set 10 | kamenka
# Processing Record 14 of Set 10 | karakol
# Processing Record 15 of Set 10 | saint-pierre
# Processing Record 16 of Set 10 | nome
# Processing Record 17 of Set 10 | deniliquin
# Processing Record 18 of Set 10 | benalla
# Processing Record 19 of Set 10 | kefamenanu
# Processing Record 20 of Set 10 | igarka
# Processing Record 21 of Set 10 | puerto madryn
# Processing Record 22 of Set 10 | fostoria
# Processing Record 23 of Set 10 | yoichi
# Processing Record 24 of Set 10 | san pedro
# Processing Record 25 of Set 10 | taungdwingyi
# Processing Record 26 of Set 10 | kristianstad
# Processing Record 27 of Set 10 | bongandanga
# Processing Record 28 of Set 10 | aizawl
# Processing Record 29 of Set 10 | nuqui
# Processing Record 30 of Set 10 | arang
# Processing Record 31 of Set 10 | kavieng
# Processing Record 32 of Set 10 | metro
# Processing Record 33 of Set 10 | moa
# Processing Record 34 of Set 10 | teknaf
# Processing Record 35 of Set 10 | matara
# Processing Record 36 of Set 10 | najran
# Processing Record 37 of Set 10 | waipawa
# Processing Record 38 of Set 10 | moose factory
# Processing Record 39 of Set 10 | port blair
# Processing Record 40 of Set 10 | tamale
# Processing Record 41 of Set 10 | hyderabad
# Processing Record 42 of Set 10 | cervo
# Processing Record 43 of Set 10 | gorontalo
# Processing Record 44 of Set 10 | sorong
# Processing Record 45 of Set 10 | singleton
# Processing Record 46 of Set 10 | tadine
# Processing Record 47 of Set 10 | hamilton
# Processing Record 48 of Set 10 | emilio carranza
# Processing Record 49 of Set 10 | jumla
# Processing Record 50 of Set 10 | broome
# Processing Record 1 of Set 11 | vila velha
# Processing Record 2 of Set 11 | ukiah
# Processing Record 3 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 11 | centralia
# Processing Record 5 of Set 11 | prince rupert
# Processing Record 6 of Set 11 | quelimane
# Processing Record 7 of Set 11 | guarapari
# Processing Record 8 of Set 11 | belyy yar
# Processing Record 9 of Set 11 | rawah
# Processing Record 10 of Set 11 | abdulino
# Processing Record 11 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 12 of Set 11 | witrivier
# City not found. Skipping...
# Processing Record 13 of Set 11 | cochrane
# Processing Record 14 of Set 11 | okhotsk
# Processing Record 15 of Set 11 | nan
# Processing Record 16 of Set 11 | portales
# Processing Record 17 of Set 11 | mwinilunga
# Processing Record 18 of Set 11 | cumaral
# Processing Record 19 of Set 11 | mpwapwa
# Processing Record 20 of Set 11 | zhezkazgan
# Processing Record 21 of Set 11 | salekhard
# Processing Record 22 of Set 11 | saryshagan
# City not found. Skipping...
# Processing Record 23 of Set 11 | eureka
# Processing Record 24 of Set 11 | marabba
# Processing Record 25 of Set 11 | tarko-sale
# Processing Record 26 of Set 11 | yulara
# Processing Record 27 of Set 11 | dawei
# Processing Record 28 of Set 11 | beringovskiy
# Processing Record 29 of Set 11 | puro
# Processing Record 30 of Set 11 | bonavista
# Processing Record 31 of Set 11 | ternate
# Processing Record 32 of Set 11 | atlantis
# Processing Record 33 of Set 11 | fallon
# Processing Record 34 of Set 11 | harper
# Processing Record 35 of Set 11 | posse
# Processing Record 36 of Set 11 | perumpavur
# Processing Record 37 of Set 11 | le port
# Processing Record 38 of Set 11 | alta floresta
# Processing Record 39 of Set 11 | burica
# City not found. Skipping...
# Processing Record 40 of Set 11 | hanting
# Processing Record 41 of Set 11 | ambilobe
# Processing Record 42 of Set 11 | kawalu
# Processing Record 43 of Set 11 | grenada
# Processing Record 44 of Set 11 | kaseda
# Processing Record 45 of Set 11 | birsk
# Processing Record 46 of Set 11 | tilichiki
# Processing Record 47 of Set 11 | sao jose da coroa grande
# Processing Record 48 of Set 11 | devonport
# Processing Record 49 of Set 11 | guerrero negro
# Processing Record 50 of Set 11 | mitsamiouli
# Processing Record 1 of Set 12 | quetzaltepec
# City not found. Skipping...
# Processing Record 2 of Set 12 | beloha
# Processing Record 3 of Set 12 | riachao das neves
# Processing Record 4 of Set 12 | nelson bay
# Processing Record 5 of Set 12 | sechenovo
# Processing Record 6 of Set 12 | ankang
# Processing Record 7 of Set 12 | mentok
# City not found. Skipping...
# Processing Record 8 of Set 12 | san jeronimo
# Processing Record 9 of Set 12 | inta
# Processing Record 10 of Set 12 | severo-kurilsk
# Processing Record 11 of Set 12 | mount darwin
# Processing Record 12 of Set 12 | marang
# Processing Record 13 of Set 12 | biggar
# Processing Record 14 of Set 12 | sinnamary
# Processing Record 15 of Set 12 | tarudant
# City not found. Skipping...
# Processing Record 16 of Set 12 | ust-nera
# Processing Record 17 of Set 12 | novaya ladoga
# Processing Record 18 of Set 12 | erzin
# Processing Record 19 of Set 12 | daokou
# Processing Record 20 of Set 12 | matay
# Processing Record 21 of Set 12 | monrovia
# Processing Record 22 of Set 12 | oktyabrskiy
# Processing Record 23 of Set 12 | teguldet
# Processing Record 24 of Set 12 | morristown
# Processing Record 25 of Set 12 | pringsewu
# Processing Record 26 of Set 12 | bo
# City not found. Skipping...
# Processing Record 27 of Set 12 | yantai
# Processing Record 28 of Set 12 | teguise
# Processing Record 29 of Set 12 | halol
# Processing Record 30 of Set 12 | bandar-e lengeh
# Processing Record 31 of Set 12 | talaya
# Processing Record 32 of Set 12 | el alto
# Processing Record 33 of Set 12 | vostok
# Processing Record 34 of Set 12 | mitu
# Processing Record 35 of Set 12 | kilrush
# Processing Record 36 of Set 12 | tazovskiy
# Processing Record 37 of Set 12 | nhulunbuy
# Processing Record 38 of Set 12 | varia
# Processing Record 39 of Set 12 | rio de janeiro
# Processing Record 40 of Set 12 | coahuayana
# Processing Record 41 of Set 12 | shahr-e babak
# Processing Record 42 of Set 12 | adamovka
# Processing Record 43 of Set 12 | watertown
# Processing Record 44 of Set 12 | gurupa
# Processing Record 45 of Set 12 | altay
# Processing Record 46 of Set 12 | tarbagatay
# Processing Record 47 of Set 12 | tocopilla
# Processing Record 48 of Set 12 | hualmay
# Processing Record 49 of Set 12 | ilhabela
# Processing Record 50 of Set 12 | constantine
# Processing Record 1 of Set 13 | teeli
# Processing Record 2 of Set 13 | huarmey
# Processing Record 3 of Set 13 | vila franca do campo
# Processing Record 4 of Set 13 | dunedin
# Processing Record 5 of Set 13 | mao
# Processing Record 6 of Set 13 | bairiki
# Processing Record 7 of Set 13 | pangai
# Processing Record 8 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 9 of Set 13 | quatre cocos
# Processing Record 10 of Set 13 | oranjemund
# Processing Record 11 of Set 13 | mirnyy
# Processing Record 12 of Set 13 | ankara
# Processing Record 13 of Set 13 | cravo norte
# Processing Record 14 of Set 13 | murom
# Processing Record 15 of Set 13 | viedma
# Processing Record 16 of Set 13 | uwayl
# City not found. Skipping...
# Processing Record 17 of Set 13 | odweyne
# Processing Record 18 of Set 13 | sandwick
# Processing Record 19 of Set 13 | dingle
# Processing Record 20 of Set 13 | pastavy
# Processing Record 21 of Set 13 | nyanza
# Processing Record 22 of Set 13 | cancun
# Processing Record 23 of Set 13 | opuwo
# Processing Record 24 of Set 13 | mattru
# Processing Record 25 of Set 13 | vila
# Processing Record 26 of Set 13 | kolosovka
# Processing Record 27 of Set 13 | superior
# Processing Record 28 of Set 13 | sindor
# Processing Record 29 of Set 13 | omboue
# Processing Record 30 of Set 13 | adre
# Processing Record 31 of Set 13 | ritchie
# Processing Record 32 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 33 of Set 13 | chiredzi
# Processing Record 34 of Set 13 | colquechaca
# Processing Record 35 of Set 13 | northam
# Processing Record 36 of Set 13 | karakendzha
# City not found. Skipping...
# Processing Record 37 of Set 13 | minas
# Processing Record 38 of Set 13 | erdaojiang
# Processing Record 39 of Set 13 | beyneu
# Processing Record 40 of Set 13 | maragogi
# Processing Record 41 of Set 13 | russell
# Processing Record 42 of Set 13 | agadir
# Processing Record 43 of Set 13 | pa sang
# Processing Record 44 of Set 13 | necochea
# Processing Record 45 of Set 13 | port macquarie
# Processing Record 46 of Set 13 | santa rosa
# Processing Record 47 of Set 13 | kolondieba
# Processing Record 48 of Set 13 | bastia
# Processing Record 49 of Set 13 | arlit
# Processing Record 50 of Set 13 | cabedelo
# Processing Record 1 of Set 14 | sehwan
# Processing Record 2 of Set 14 | geraldton
# Processing Record 3 of Set 14 | paragominas
# Processing Record 4 of Set 14 | rioja
# Processing Record 5 of Set 14 | male
# Processing Record 6 of Set 14 | nabire
# Processing Record 7 of Set 14 | kudat
# Processing Record 8 of Set 14 | neya
# Processing Record 9 of Set 14 | ixtapa
# Processing Record 10 of Set 14 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 14 | akureyri
# Processing Record 12 of Set 14 | piet retief
# Processing Record 13 of Set 14 | kasongo
# Processing Record 14 of Set 14 | shenjiamen
# Processing Record 15 of Set 14 | road town
# Processing Record 16 of Set 14 | codrington
# Processing Record 17 of Set 14 | calvinia
# Processing Record 18 of Set 14 | ust-tsilma
# Processing Record 19 of Set 14 | emmett
# Processing Record 20 of Set 14 | carutapera
# Processing Record 21 of Set 14 | sri aman
# Processing Record 22 of Set 14 | shieli
# Processing Record 23 of Set 14 | sisimiut
# Processing Record 24 of Set 14 | aripuana
# Processing Record 25 of Set 14 | kauhajoki
# Processing Record 26 of Set 14 | puerto escondido
# Processing Record 27 of Set 14 | bilibino
# Processing Record 28 of Set 14 | witu
# Processing Record 29 of Set 14 | swift current
# Processing Record 30 of Set 14 | humaita
# Processing Record 31 of Set 14 | balkanabat
# Processing Record 32 of Set 14 | kurilsk
# Processing Record 33 of Set 14 | rrogozhine
# Processing Record 34 of Set 14 | bandarban
# Processing Record 35 of Set 14 | praia
# Processing Record 36 of Set 14 | sarahan
# Processing Record 37 of Set 14 | emerald
# Processing Record 38 of Set 14 | mumford
# Processing Record 39 of Set 14 | new ross
# Processing Record 40 of Set 14 | aksum
# Processing Record 41 of Set 14 | mezibori
# Processing Record 42 of Set 14 | churapcha
# Processing Record 43 of Set 14 | rocha
# Processing Record 44 of Set 14 | zlotoryja
# Processing Record 45 of Set 14 | micheweni
# Processing Record 46 of Set 14 | codajas
# Processing Record 47 of Set 14 | hutchinson
# Processing Record 48 of Set 14 | abha
# Processing Record 49 of Set 14 | wolfeboro
# Processing Record 50 of Set 14 | gao
# Processing Record 1 of Set 15 | chapais
# Processing Record 2 of Set 15 | gobabis
# Processing Record 3 of Set 15 | tuy hoa
# Processing Record 4 of Set 15 | hihifo
# City not found. Skipping...
# Processing Record 5 of Set 15 | artyom
# Processing Record 6 of Set 15 | jibuti
# Processing Record 7 of Set 15 | koster
# Processing Record 8 of Set 15 | chalus
# Processing Record 9 of Set 15 | genhe
# Processing Record 10 of Set 15 | saratoga springs
# Processing Record 11 of Set 15 | mombetsu
# Processing Record 12 of Set 15 | san vicente
# Processing Record 13 of Set 15 | tamasi
# Processing Record 14 of Set 15 | verkhoyansk
# Processing Record 15 of Set 15 | mangai
# Processing Record 16 of Set 15 | zabid
# Processing Record 17 of Set 15 | kiama
# Processing Record 18 of Set 15 | ruatoria
# City not found. Skipping...
# Processing Record 19 of Set 15 | kegayli
# City not found. Skipping...
# Processing Record 20 of Set 15 | guhagar
# Processing Record 21 of Set 15 | macaubas
# Processing Record 22 of Set 15 | gidam
# Processing Record 23 of Set 15 | pinsk
# Processing Record 24 of Set 15 | mutsamudu
# City not found. Skipping...
# Processing Record 25 of Set 15 | kadhan
# Processing Record 26 of Set 15 | fianga
# City not found. Skipping...
# Processing Record 27 of Set 15 | campeche
# Processing Record 28 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 29 of Set 15 | novyy urgal
# Processing Record 30 of Set 15 | gazanjyk
# Processing Record 31 of Set 15 | crab hill
# City not found. Skipping...
# Processing Record 32 of Set 15 | kutum
# Processing Record 33 of Set 15 | lincoln
# Processing Record 34 of Set 15 | sistranda
# Processing Record 35 of Set 15 | navalmoral de la mata
# Processing Record 36 of Set 15 | ishigaki
# Processing Record 37 of Set 15 | denpasar
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 674

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Cape Town -33.9258   18.4232     61.12        81          61
# 1       Araouane  18.9048   -3.5265     92.89         8           8
# 2  Bambanglipuro  -7.9500  110.2833     76.55        86          98
# 3         Lompoc  34.6391 -120.4579     69.94        74          20
# 4       Tasiilaq  65.6145  -37.6368     33.96        75          57
#
#    Wind Speed Current Description Country
# 0        1.01       broken clouds      ZA
# 1        7.85           clear sky      ML
# 2       10.87     overcast clouds      ID
# 3       11.50          few clouds      US
# 4        3.06       broken clouds      GL

# %%
# Reorder columns in DataFrame
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]

city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Cape Town      ZA -33.9258   18.4232     61.12        81          61
# 1       Araouane      ML  18.9048   -3.5265     92.89         8           8
# 2  Bambanglipuro      ID  -7.9500  110.2833     76.55        86          98
# 3         Lompoc      US  34.6391 -120.4579     69.94        74          20
# 4       Tasiilaq      GL  65.6145  -37.6368     33.96        75          57
# 5         Arcata      US  40.8665 -124.0828     73.20        66           1
# 6    Provideniya      RU  64.3833 -173.3000     37.51        70          20
# 7    Pangnirtung      CA  66.1451  -65.7125     32.40        78          17
# 8      Carnarvon      AU -24.8667  113.6333     53.67        94          75
# 9   Punta Arenas      CL -53.1500  -70.9167     46.51        61          40
#
#    Wind Speed Current Description
# 0        1.01       broken clouds
# 1        7.85           clear sky
# 2       10.87     overcast clouds
# 3       11.50          few clouds
# 4        3.06       broken clouds
# 5        3.00           clear sky
# 6       11.18          few clouds
# 7        1.45          few clouds
# 8        6.91       broken clouds
# 9       13.80    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
